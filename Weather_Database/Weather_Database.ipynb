# %%
import pandas as pd
import numpy as np
import requests

import pprint as pp 
from citipy import citipy 
from config import weather_api_key
import time

# %%
#Create a set of random latitude an d longitude combination
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
coordinates[0:5]
# Out:
# [(37.91651109158353, 178.90718178100678),
#  (32.569200698220115, 17.80844171384834),
#  (-42.388215287888194, 18.39136555026775),
#  (89.20527037914854, 19.44835585992604),
#  (-68.83171460006733, 136.87781093062722)]

# %%
# Starting URL for Weather Map API Call.
url =f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Create an empty list to hold the weather data.
city_data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through city Lists 
for i, city in list(enumerate(cities)):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        #time.sleep(60)
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url =f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}&q={city.replace(" ","+")}'
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    # Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
        #pp.pprint(city_weather)
       
        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        #city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         #"Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | surt
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | dudinka
# Processing Record 7 of Set 1 | half moon bay
# Processing Record 8 of Set 1 | mbaiki
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | trojes
# Processing Record 13 of Set 1 | taoudenni
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | utinga
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | dyersburg
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | tuatapere
# Processing Record 23 of Set 1 | port shepstone
# Processing Record 24 of Set 1 | arkhangelos
# City not found. Skipping
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 26 of Set 1 | port blair
# Processing Record 27 of Set 1 | vila franca do campo
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | balykshi
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | hashtrud
# Processing Record 34 of Set 1 | anadyr
# Processing Record 35 of Set 1 | cockburn town
# Processing Record 36 of Set 1 | armidale
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | halifax
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | ballina
# Processing Record 42 of Set 1 | nerchinskiy zavod
# Processing Record 43 of Set 1 | sol-iletsk
# Processing Record 44 of Set 1 | coahuayana
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | cervo
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | olafsvik
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | bodden town
# Processing Record 2 of Set 2 | yumen
# Processing Record 3 of Set 2 | westport
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | ankpa
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping
# Processing Record 9 of Set 2 | lifford
# Processing Record 10 of Set 2 | yunhe
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 12 of Set 2 | griffith
# Processing Record 13 of Set 2 | san patricio
# Processing Record 14 of Set 2 | derzhavinsk
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | shenjiamen
# Processing Record 17 of Set 2 | yar-sale
# Processing Record 18 of Set 2 | abdanan
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | tomatlan
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | orlik
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | codrington
# Processing Record 28 of Set 2 | mikuni
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | yairipok
# Processing Record 33 of Set 2 | plettenberg bay
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | los llanos de aridane
# Processing Record 37 of Set 2 | svetlaya
# Processing Record 38 of Set 2 | amapa
# Processing Record 39 of Set 2 | sakakah
# Processing Record 40 of Set 2 | erenhot
# Processing Record 41 of Set 2 | tigil
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | mount isa
# Processing Record 44 of Set 2 | rikitea
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | cabo rojo
# Processing Record 47 of Set 2 | mattru
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | solntsevo
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | kabansk
# Processing Record 5 of Set 3 | pangnirtung
# Processing Record 6 of Set 3 | aksarka
# Processing Record 7 of Set 3 | wewak
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | flin flon
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | alta floresta
# Processing Record 12 of Set 3 | lanzhou
# Processing Record 13 of Set 3 | geilo
# Processing Record 14 of Set 3 | aripuana
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | padang
# Processing Record 19 of Set 3 | warmbad
# Processing Record 20 of Set 3 | bolungarvik
# City not found. Skipping
# Processing Record 21 of Set 3 | minab
# Processing Record 22 of Set 3 | kouqian
# Processing Record 23 of Set 3 | anchorage
# Processing Record 24 of Set 3 | nadym
# Processing Record 25 of Set 3 | cheremukhovo
# Processing Record 26 of Set 3 | tiznit
# Processing Record 27 of Set 3 | jinchengjiang
# City not found. Skipping
# Processing Record 28 of Set 3 | ketchikan
# Processing Record 29 of Set 3 | korla
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 34 of Set 3 | sunndalsora
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | ucluelet
# Processing Record 39 of Set 3 | montenegro
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | kostomuksha
# Processing Record 43 of Set 3 | oussouye
# Processing Record 44 of Set 3 | acapulco
# Processing Record 45 of Set 3 | seoul
# Processing Record 46 of Set 3 | zhangjiakou
# Processing Record 47 of Set 3 | port hedland
# Processing Record 48 of Set 3 | saint marys
# Processing Record 49 of Set 3 | izhevskoye
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | ponta delgada
# Processing Record 3 of Set 4 | gonzales
# Processing Record 4 of Set 4 | honiara
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | coos bay
# Processing Record 7 of Set 4 | paka
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | richards bay
# Processing Record 10 of Set 4 | sur
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | koboko
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | iracoubo
# Processing Record 16 of Set 4 | cedar city
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | talcahuano
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | jieshi
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | belaya gora
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | sabrum
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | sao tome
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | porto walter
# Processing Record 31 of Set 4 | evensk
# Processing Record 32 of Set 4 | ola
# Processing Record 33 of Set 4 | basco
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | powell
# Processing Record 37 of Set 4 | hirara
# Processing Record 38 of Set 4 | vriezenveen
# Processing Record 39 of Set 4 | toliary
# City not found. Skipping
# Processing Record 40 of Set 4 | ahuimanu
# Processing Record 41 of Set 4 | byron bay
# Processing Record 42 of Set 4 | campeche
# Processing Record 43 of Set 4 | axim
# Processing Record 44 of Set 4 | manzanillo
# Processing Record 45 of Set 4 | karwar
# Processing Record 46 of Set 4 | broken hill
# Processing Record 47 of Set 4 | morant bay
# Processing Record 48 of Set 4 | leisure city
# Processing Record 49 of Set 4 | bousso
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | camocim
# Processing Record 2 of Set 5 | bonavista
# Processing Record 3 of Set 5 | kontagora
# Processing Record 4 of Set 5 | chicama
# Processing Record 5 of Set 5 | nizwa
# Processing Record 6 of Set 5 | kavaratti
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | pocone
# Processing Record 11 of Set 5 | gat
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping
# Processing Record 14 of Set 5 | shitanjing
# Processing Record 15 of Set 5 | lata
# Processing Record 16 of Set 5 | lubumbashi
# Processing Record 17 of Set 5 | jaworzno
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | chuy
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | riyadh
# Processing Record 22 of Set 5 | olinda
# Processing Record 23 of Set 5 | payakumbuh
# Processing Record 24 of Set 5 | casambalangan
# Processing Record 25 of Set 5 | lasa
# Processing Record 26 of Set 5 | rocha
# Processing Record 27 of Set 5 | crossville
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | babag
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping
# Processing Record 31 of Set 5 | alyangula
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | tual
# Processing Record 34 of Set 5 | agropoli
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping
# Processing Record 36 of Set 5 | havre-saint-pierre
# Processing Record 37 of Set 5 | sao paulo de olivenca
# Processing Record 38 of Set 5 | praia da vitoria
# Processing Record 39 of Set 5 | san javier
# Processing Record 40 of Set 5 | phan rang
# City not found. Skipping
# Processing Record 41 of Set 5 | bargal
# City not found. Skipping
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | nome
# Processing Record 45 of Set 5 | venezuela
# Processing Record 46 of Set 5 | san cristobal
# Processing Record 47 of Set 5 | catuday
# Processing Record 48 of Set 5 | abrau-dyurso
# Processing Record 49 of Set 5 | aginskoye
# Processing Record 50 of Set 5 | yelnya
# Processing Record 1 of Set 6 | kodinsk
# Processing Record 2 of Set 6 | nizhneudinsk
# Processing Record 3 of Set 6 | khani
# Processing Record 4 of Set 6 | dabat
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | mackay
# Processing Record 8 of Set 6 | nayoro
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | clarence town
# Processing Record 12 of Set 6 | bridlington
# Processing Record 13 of Set 6 | dentsville
# Processing Record 14 of Set 6 | phek
# Processing Record 15 of Set 6 | puerto baquerizo moreno
# Processing Record 16 of Set 6 | rio grande
# Processing Record 17 of Set 6 | damghan
# Processing Record 18 of Set 6 | baker city
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | lake havasu city
# Processing Record 22 of Set 6 | sinjar
# Processing Record 23 of Set 6 | unidad
# Processing Record 24 of Set 6 | nizhneyansk
# City not found. Skipping
# Processing Record 25 of Set 6 | attawapiskat
# City not found. Skipping
# Processing Record 26 of Set 6 | kamaishi
# Processing Record 27 of Set 6 | buckeye
# Processing Record 28 of Set 6 | namwala
# Processing Record 29 of Set 6 | holme
# Processing Record 30 of Set 6 | bandarbeyla
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping
# Processing Record 32 of Set 6 | raichur
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | longyan
# Processing Record 35 of Set 6 | gaya
# Processing Record 36 of Set 6 | haines junction
# Processing Record 37 of Set 6 | fallon
# Processing Record 38 of Set 6 | hanna
# Processing Record 39 of Set 6 | kampene
# Processing Record 40 of Set 6 | georgiyevskoye
# Processing Record 41 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 6 | grand forks
# Processing Record 43 of Set 6 | labrea
# Processing Record 44 of Set 6 | mocuba
# Processing Record 45 of Set 6 | contamana
# Processing Record 46 of Set 6 | alihe
# Processing Record 47 of Set 6 | yancheng
# Processing Record 48 of Set 6 | pimenta bueno
# Processing Record 49 of Set 6 | asau
# Processing Record 50 of Set 6 | plotnikovo
# Processing Record 1 of Set 7 | kewanee
# Processing Record 2 of Set 7 | akureyri
# Processing Record 3 of Set 7 | isangel
# Processing Record 4 of Set 7 | ylivieska
# Processing Record 5 of Set 7 | pahrump
# Processing Record 6 of Set 7 | severodvinsk
# Processing Record 7 of Set 7 | jurado
# Processing Record 8 of Set 7 | callaway
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | biak
# Processing Record 12 of Set 7 | moose factory
# Processing Record 13 of Set 7 | suez
# Processing Record 14 of Set 7 | akdepe
# Processing Record 15 of Set 7 | namibe
# Processing Record 16 of Set 7 | nautla
# Processing Record 17 of Set 7 | pacifica
# Processing Record 18 of Set 7 | raudeberg
# Processing Record 19 of Set 7 | san vicente
# Processing Record 20 of Set 7 | mahebourg
# Processing Record 21 of Set 7 | maceio
# Processing Record 22 of Set 7 | deputatskiy
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | nanortalik
# Processing Record 25 of Set 7 | am timan
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | dukat
# Processing Record 28 of Set 7 | sayat
# Processing Record 29 of Set 7 | emerald
# Processing Record 30 of Set 7 | bur gabo
# City not found. Skipping
# Processing Record 31 of Set 7 | mayor pablo lagerenza
# Processing Record 32 of Set 7 | macklin
# Processing Record 33 of Set 7 | yarada
# Processing Record 34 of Set 7 | alice springs
# Processing Record 35 of Set 7 | hihifo
# City not found. Skipping
# Processing Record 36 of Set 7 | whitehorse
# Processing Record 37 of Set 7 | hobyo
# Processing Record 38 of Set 7 | port stanley
# Processing Record 39 of Set 7 | haademeeste
# City not found. Skipping
# Processing Record 40 of Set 7 | hithadhoo
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | vallenar
# Processing Record 43 of Set 7 | poum
# Processing Record 44 of Set 7 | verkhniy fiagdon
# Processing Record 45 of Set 7 | chokurdakh
# Processing Record 46 of Set 7 | rapid city
# Processing Record 47 of Set 7 | zeya
# Processing Record 48 of Set 7 | oistins
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | omsukchan
# Processing Record 1 of Set 8 | arraial do cabo
# Processing Record 2 of Set 8 | hohoe
# Processing Record 3 of Set 8 | makakilo city
# Processing Record 4 of Set 8 | kiunga
# Processing Record 5 of Set 8 | kiama
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | bolshoy tsaryn
# City not found. Skipping
# Processing Record 8 of Set 8 | nazca
# Processing Record 9 of Set 8 | ancud
# Processing Record 10 of Set 8 | san rafael del sur
# Processing Record 11 of Set 8 | davidson
# Processing Record 12 of Set 8 | lufilufi
# Processing Record 13 of Set 8 | sahrak
# City not found. Skipping
# Processing Record 14 of Set 8 | pontes e lacerda
# Processing Record 15 of Set 8 | panji
# Processing Record 16 of Set 8 | lolua
# City not found. Skipping
# Processing Record 17 of Set 8 | mecca
# Processing Record 18 of Set 8 | mahajanga
# Processing Record 19 of Set 8 | yakeshi
# Processing Record 20 of Set 8 | umm kaddadah
# Processing Record 21 of Set 8 | tessalit
# Processing Record 22 of Set 8 | manokwari
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | izumo
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | havelock
# Processing Record 27 of Set 8 | narsaq
# Processing Record 28 of Set 8 | norman wells
# Processing Record 29 of Set 8 | auki
# Processing Record 30 of Set 8 | marsa matruh
# Processing Record 31 of Set 8 | angoram
# Processing Record 32 of Set 8 | caranavi
# Processing Record 33 of Set 8 | paamiut
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | arlit
# Processing Record 36 of Set 8 | sorland
# Processing Record 37 of Set 8 | maghama
# City not found. Skipping
# Processing Record 38 of Set 8 | toora-khem
# Processing Record 39 of Set 8 | kokkola
# Processing Record 40 of Set 8 | vila
# Processing Record 41 of Set 8 | kamenskoye
# City not found. Skipping
# Processing Record 42 of Set 8 | shimoda
# Processing Record 43 of Set 8 | yanam
# Processing Record 44 of Set 8 | the valley
# Processing Record 45 of Set 8 | feijo
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | sorong
# Processing Record 48 of Set 8 | caravelas
# Processing Record 49 of Set 8 | brae
# Processing Record 50 of Set 8 | santa rosa
# Processing Record 1 of Set 9 | sibolga
# Processing Record 2 of Set 9 | gilgit
# Processing Record 3 of Set 9 | ituporanga
# Processing Record 4 of Set 9 | saint-joseph
# Processing Record 5 of Set 9 | qui nhon
# Processing Record 6 of Set 9 | urumqi
# Processing Record 7 of Set 9 | socuellamos
# Processing Record 8 of Set 9 | kanepi
# Processing Record 9 of Set 9 | buraydah
# Processing Record 10 of Set 9 | barra do bugres
# Processing Record 11 of Set 9 | daru
# Processing Record 12 of Set 9 | vesyegonsk
# Processing Record 13 of Set 9 | mbamba
# Processing Record 14 of Set 9 | port augusta
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | sistranda
# Processing Record 17 of Set 9 | dalvik
# Processing Record 18 of Set 9 | arti
# Processing Record 19 of Set 9 | panama city
# Processing Record 20 of Set 9 | pervomayskoye
# Processing Record 21 of Set 9 | cooma
# Processing Record 22 of Set 9 | matay
# Processing Record 23 of Set 9 | salinopolis
# Processing Record 24 of Set 9 | visby
# Processing Record 25 of Set 9 | klaksvik
# Processing Record 26 of Set 9 | honningsvag
# Processing Record 27 of Set 9 | udachnyy
# Processing Record 28 of Set 9 | chicago
# Processing Record 29 of Set 9 | ijaki
# City not found. Skipping
# Processing Record 30 of Set 9 | huambo
# Processing Record 31 of Set 9 | peterhead
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | bakel
# Processing Record 34 of Set 9 | moyale
# Processing Record 35 of Set 9 | doha
# Processing Record 36 of Set 9 | havre
# Processing Record 37 of Set 9 | varberg
# Processing Record 38 of Set 9 | kerki
# City not found. Skipping
# Processing Record 39 of Set 9 | leshan
# Processing Record 40 of Set 9 | harlingen
# Processing Record 41 of Set 9 | abnub
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | pacaembu
# Processing Record 44 of Set 9 | vigrestad
# Processing Record 45 of Set 9 | illapel
# Processing Record 46 of Set 9 | zaozerne
# Processing Record 47 of Set 9 | chipping sodbury
# Processing Record 48 of Set 9 | klyuchi
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | tazmalt
# Processing Record 1 of Set 10 | cintalapa
# Processing Record 2 of Set 10 | iquique
# Processing Record 3 of Set 10 | beaverlodge
# Processing Record 4 of Set 10 | kachiry
# Processing Record 5 of Set 10 | hamilton
# Processing Record 6 of Set 10 | syasstroy
# Processing Record 7 of Set 10 | tarauaca
# Processing Record 8 of Set 10 | vaitape
# Processing Record 9 of Set 10 | baymak
# Processing Record 10 of Set 10 | santa cruz
# Processing Record 11 of Set 10 | rungata
# City not found. Skipping
# Processing Record 12 of Set 10 | lavrentiya
# Processing Record 13 of Set 10 | nevsehir
# Processing Record 14 of Set 10 | santiago del estero
# Processing Record 15 of Set 10 | grand river south east
# City not found. Skipping
# Processing Record 16 of Set 10 | tabas
# Processing Record 17 of Set 10 | san juan
# Processing Record 18 of Set 10 | belyy yar
# Processing Record 19 of Set 10 | yerofey pavlovich
# Processing Record 20 of Set 10 | port-cartier
# Processing Record 21 of Set 10 | melo
# Processing Record 22 of Set 10 | plouzane
# Processing Record 23 of Set 10 | palora
# Processing Record 24 of Set 10 | litovko
# Processing Record 25 of Set 10 | namie
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | gaoual
# Processing Record 28 of Set 10 | krasnoyarka
# Processing Record 29 of Set 10 | iquitos
# Processing Record 30 of Set 10 | lorengau
# Processing Record 31 of Set 10 | zhigansk
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping
# Processing Record 33 of Set 10 | caribou
# Processing Record 34 of Set 10 | mae sai
# Processing Record 35 of Set 10 | nanma
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | pandan
# Processing Record 38 of Set 10 | puerto narino
# Processing Record 39 of Set 10 | sechura
# Processing Record 40 of Set 10 | sungaipenuh
# Processing Record 41 of Set 10 | lafiagi
# Processing Record 42 of Set 10 | san matias
# Processing Record 43 of Set 10 | jacareacanga
# Processing Record 44 of Set 10 | soure
# Processing Record 45 of Set 10 | sakit
# Processing Record 46 of Set 10 | faya
# Processing Record 47 of Set 10 | porto novo
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | lagoa
# Processing Record 50 of Set 10 | kandrian
# Processing Record 1 of Set 11 | lander
# Processing Record 2 of Set 11 | miyang
# Processing Record 3 of Set 11 | vao
# Processing Record 4 of Set 11 | jalostotitlan
# Processing Record 5 of Set 11 | awbari
# Processing Record 6 of Set 11 | ribnica
# Processing Record 7 of Set 11 | alpena
# Processing Record 8 of Set 11 | bereda
# Processing Record 9 of Set 11 | port-gentil
# Processing Record 10 of Set 11 | puerto escondido
# Processing Record 11 of Set 11 | koutsouras
# Processing Record 12 of Set 11 | prince albert
# Processing Record 13 of Set 11 | balkanabat
# Processing Record 14 of Set 11 | hay river
# Processing Record 15 of Set 11 | kindia
# Processing Record 16 of Set 11 | vedaranniyam
# City not found. Skipping
# Processing Record 17 of Set 11 | ternate
# Processing Record 18 of Set 11 | noshiro
# Processing Record 19 of Set 11 | creteil
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | urdzhar
# City not found. Skipping
# Processing Record 22 of Set 11 | vanavara
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | marzuq
# Processing Record 25 of Set 11 | panaba
# Processing Record 26 of Set 11 | poshekhonye
# Processing Record 27 of Set 11 | ahipara
# Processing Record 28 of Set 11 | nantucket
# Processing Record 29 of Set 11 | qasigiannguit
# Processing Record 30 of Set 11 | burnie
# Processing Record 31 of Set 11 | sao filipe
# Processing Record 32 of Set 11 | quatre cocos
# Processing Record 33 of Set 11 | zeerust
# Processing Record 34 of Set 11 | mpophomeni
# Processing Record 35 of Set 11 | jawhar
# Processing Record 36 of Set 11 | hofn
# Processing Record 37 of Set 11 | walvis bay
# Processing Record 38 of Set 11 | fortuna
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | anyang
# Processing Record 41 of Set 11 | tokur
# Processing Record 42 of Set 11 | weinan
# Processing Record 43 of Set 11 | tarko-sale
# Processing Record 44 of Set 11 | noyabrsk
# Processing Record 45 of Set 11 | batagay
# Processing Record 46 of Set 11 | inhambane
# Processing Record 47 of Set 11 | gravdal
# Processing Record 48 of Set 11 | ninghai
# Processing Record 49 of Set 11 | victoria
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | bensonville
# Processing Record 2 of Set 12 | atar
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping
# Processing Record 4 of Set 12 | antofagasta
# Processing Record 5 of Set 12 | muisne
# Processing Record 6 of Set 12 | mpongwe
# Processing Record 7 of Set 12 | yaroslavl
# Processing Record 8 of Set 12 | sioux lookout
# Processing Record 9 of Set 12 | waipawa
# Processing Record 10 of Set 12 | belm
# Processing Record 11 of Set 12 | saint-pierre
# Processing Record 12 of Set 12 | curup
# Processing Record 13 of Set 12 | one hundred mile house
# City not found. Skipping
# Processing Record 14 of Set 12 | destin
# Processing Record 15 of Set 12 | fairbanks
# Processing Record 16 of Set 12 | turochak
# Processing Record 17 of Set 12 | ouadda
# Processing Record 18 of Set 12 | jinan
# Processing Record 19 of Set 12 | nishihara
# Processing Record 20 of Set 12 | te anau
# Processing Record 21 of Set 12 | susangerd
# Processing Record 22 of Set 12 | thinadhoo
# Processing Record 23 of Set 12 | patacamaya
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | teya
# Processing Record 26 of Set 12 | lima
# Processing Record 27 of Set 12 | sangin
# Processing Record 28 of Set 12 | ghogha
# Processing Record 29 of Set 12 | miquelon
# Processing Record 30 of Set 12 | huejuquilla el alto
# Processing Record 31 of Set 12 | pietersburg
# Processing Record 32 of Set 12 | babanusah
# City not found. Skipping
# Processing Record 33 of Set 12 | san roque
# Processing Record 34 of Set 12 | charters towers
# Processing Record 35 of Set 12 | jingdezhen
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | tselinnoye
# Processing Record 38 of Set 12 | copperas cove
# Processing Record 39 of Set 12 | ruatoria
# City not found. Skipping
# Processing Record 40 of Set 12 | svetlyy
# Processing Record 41 of Set 12 | marienburg
# Processing Record 42 of Set 12 | naifaru
# Processing Record 43 of Set 12 | louis trichardt
# Processing Record 44 of Set 12 | paraiso
# Processing Record 45 of Set 12 | baykit
# Processing Record 46 of Set 12 | sanguem
# Processing Record 47 of Set 12 | koungou
# Processing Record 48 of Set 12 | bestobe
# Processing Record 49 of Set 12 | concordia
# Processing Record 50 of Set 12 | ondjiva
# Processing Record 1 of Set 13 | moundou
# Processing Record 2 of Set 13 | ixtapa
# Processing Record 3 of Set 13 | pemba
# Processing Record 4 of Set 13 | sergeyevka
# Processing Record 5 of Set 13 | djibo
# Processing Record 6 of Set 13 | oranjemund
# Processing Record 7 of Set 13 | nambucca heads
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | great malvern
# Processing Record 10 of Set 13 | findlay
# Processing Record 11 of Set 13 | campbell river
# Processing Record 12 of Set 13 | canico
# Processing Record 13 of Set 13 | sheboygan
# Processing Record 14 of Set 13 | saint george
# Processing Record 15 of Set 13 | college
# Processing Record 16 of Set 13 | gibsons
# Processing Record 17 of Set 13 | kyshtovka
# Processing Record 18 of Set 13 | palmer
# Processing Record 19 of Set 13 | camacha
# Processing Record 20 of Set 13 | naze
# Processing Record 21 of Set 13 | joshimath
# Processing Record 22 of Set 13 | killybegs
# Processing Record 23 of Set 13 | kadykchan
# City not found. Skipping
# Processing Record 24 of Set 13 | sutton
# Processing Record 25 of Set 13 | biltine
# Processing Record 26 of Set 13 | abu samrah
# Processing Record 27 of Set 13 | goundam
# Processing Record 28 of Set 13 | matara
# Processing Record 29 of Set 13 | assis
# Processing Record 30 of Set 13 | timizart
# Processing Record 31 of Set 13 | kudahuvadhoo
# Processing Record 32 of Set 13 | nioro
# Processing Record 33 of Set 13 | abonnema
# Processing Record 34 of Set 13 | ugoofaaru
# Processing Record 35 of Set 13 | haimen
# Processing Record 36 of Set 13 | champerico
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | grand-santi
# Processing Record 39 of Set 13 | pisz
# Processing Record 40 of Set 13 | umzimvubu
# City not found. Skipping
# Processing Record 41 of Set 13 | baishishan
# Processing Record 42 of Set 13 | soria
# Processing Record 43 of Set 13 | myaundzha
# Processing Record 44 of Set 13 | grindavik
# Processing Record 45 of Set 13 | ajdabiya
# Processing Record 46 of Set 13 | muravlenko
# Processing Record 47 of Set 13 | zalantun
# Processing Record 48 of Set 13 | beberibe
# Processing Record 49 of Set 13 | jining
# Processing Record 50 of Set 13 | canton
# Processing Record 1 of Set 14 | yeppoon
# Processing Record 2 of Set 14 | bayeux
# Processing Record 3 of Set 14 | bontang
# Processing Record 4 of Set 14 | vila praia de ancora
# Processing Record 5 of Set 14 | manono
# Processing Record 6 of Set 14 | mala tokmachka
# Processing Record 7 of Set 14 | mitsamiouli
# Processing Record 8 of Set 14 | stokmarknes
# Processing Record 9 of Set 14 | muroto
# Processing Record 10 of Set 14 | srandakan
# Processing Record 11 of Set 14 | maneadero
# Processing Record 12 of Set 14 | valmiera
# Processing Record 13 of Set 14 | yubari
# Processing Record 14 of Set 14 | tukrah
# Processing Record 15 of Set 14 | valparaiso
# Processing Record 16 of Set 14 | kastamonu
# Processing Record 17 of Set 14 | salym
# Processing Record 18 of Set 14 | maniitsoq
# Processing Record 19 of Set 14 | pinsk
# Processing Record 20 of Set 14 | iowa city
# Processing Record 21 of Set 14 | cayenne
# Processing Record 22 of Set 14 | fare
# Processing Record 23 of Set 14 | turmalina
# Processing Record 24 of Set 14 | jalu
# Processing Record 25 of Set 14 | pavlodar
# Processing Record 26 of Set 14 | takoradi
# Processing Record 27 of Set 14 | ambilobe
# Processing Record 28 of Set 14 | staraya poltavka
# Processing Record 29 of Set 14 | muli
# Processing Record 30 of Set 14 | asosa
# Processing Record 31 of Set 14 | alegrete
# Processing Record 32 of Set 14 | pangody
# Processing Record 33 of Set 14 | fereydunshahr
# Processing Record 34 of Set 14 | safaga
# Processing Record 35 of Set 14 | panambi
# Processing Record 36 of Set 14 | acari
# Processing Record 37 of Set 14 | watertown
# Processing Record 38 of Set 14 | komsomolskiy
# Processing Record 39 of Set 14 | kaeo
# Processing Record 40 of Set 14 | rabo de peixe
# Processing Record 41 of Set 14 | mikkeli
# Processing Record 42 of Set 14 | talnakh
# Processing Record 43 of Set 14 | murray bridge
# Processing Record 44 of Set 14 | nowa deba
# Processing Record 45 of Set 14 | varkaus
# Processing Record 46 of Set 14 | vsetaty
# Processing Record 47 of Set 14 | mirnyy
# Processing Record 48 of Set 14 | beisfjord
# Processing Record 49 of Set 14 | palana
# Processing Record 50 of Set 14 | puerto carreno
# Processing Record 1 of Set 15 | le port
# Processing Record 2 of Set 15 | popondetta
# Processing Record 3 of Set 15 | yirol
# City not found. Skipping
# Processing Record 4 of Set 15 | constantine
# Processing Record 5 of Set 15 | harnosand
# Processing Record 6 of Set 15 | wicklow
# Processing Record 7 of Set 15 | kupang
# Processing Record 8 of Set 15 | puerto ayacucho
# Processing Record 9 of Set 15 | goure
# Processing Record 10 of Set 15 | batangafo
# Processing Record 11 of Set 15 | kokoda
# Processing Record 12 of Set 15 | durban
# Processing Record 13 of Set 15 | sampit
# Processing Record 14 of Set 15 | mareeba
# Processing Record 15 of Set 15 | bilma
# Processing Record 16 of Set 15 | knoxville
# Processing Record 17 of Set 15 | ayna
# Processing Record 18 of Set 15 | hambantota
# Processing Record 19 of Set 15 | berlevag
# Processing Record 20 of Set 15 | khrebtovaya
# Processing Record 21 of Set 15 | tevaitoa
# Processing Record 22 of Set 15 | sangar
# Processing Record 23 of Set 15 | brigantine
# Processing Record 24 of Set 15 | vrangel
# Processing Record 25 of Set 15 | darhan
# Processing Record 26 of Set 15 | lubango
# Processing Record 27 of Set 15 | klenovyy
# Processing Record 28 of Set 15 | lewiston
# Processing Record 29 of Set 15 | crestview
# Processing Record 30 of Set 15 | mildura
# Processing Record 31 of Set 15 | skibbereen
# Processing Record 32 of Set 15 | miyoshi
# Processing Record 33 of Set 15 | songea
# Processing Record 34 of Set 15 | fayaoue
# Processing Record 35 of Set 15 | werda
# Processing Record 36 of Set 15 | bonthe
# Processing Record 37 of Set 15 | bull savanna
# Processing Record 38 of Set 15 | iskateley
# Processing Record 39 of Set 15 | ilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nikolskoye      RU  59.7035   30.7861     53.87        79         100
# 1          Surt      LY  31.2089   16.5887     77.67        70          16
# 2      Hermanus      ZA -34.4187   19.2345     68.90        66           8
# 3  Longyearbyen      SJ  78.2186   15.6401     21.04        73          20
# 4   New Norfolk      AU -42.7826  147.0587     47.70        65          41
#
#    Wind Speed Current Description
# 0        6.35     overcast clouds
# 1       17.20          few clouds
# 2        6.02           clear sky
# 3        8.05          few clouds
# 4        1.99    scattered clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nikolskoye      RU  59.7035   30.7861     53.87        79         100
# 1            Surt      LY  31.2089   16.5887     77.67        70          16
# 2        Hermanus      ZA -34.4187   19.2345     68.90        66           8
# 3    Longyearbyen      SJ  78.2186   15.6401     21.04        73          20
# 4     New Norfolk      AU -42.7826  147.0587     47.70        65          41
# 5         Dudinka      RU  69.4058   86.1778     18.64        84          96
# 6   Half Moon Bay      US  37.4636 -122.4286     60.10        78          40
# 7          Mbaiki      CF   3.8678   17.9892     79.34        80          89
# 8  Ribeira Grande      PT  38.5167  -28.7000     73.80        73          40
# 9          Hasaki      JP  35.7333  140.8333     68.40        86          36
#
#    Wind Speed Current Description
# 0        6.35     overcast clouds
# 1       17.20          few clouds
# 2        6.02           clear sky
# 3        8.05          few clouds
# 4        1.99    scattered clouds
# 5       16.46     overcast clouds
# 6        0.00    scattered clouds
# 7        2.66          light rain
# 8       18.41    scattered clouds
# 9        6.93    scattered clouds

# %%
#Export the DataFrame as CSV file
output_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_file, index_label="City_ID")
